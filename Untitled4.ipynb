# %% [markdown]
# <a href="https://colab.research.google.com/github/anmol0720/Getting-Started-with-SVM/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy as stats

#for advanced plotting
import seaborn as sns; sns.set() #Invoking

# %% [markdown]
# Creating a Sample DataSet for the activity of volcanos

# %%
from sklearn.datasets.samples_generator import make_blobs

X,y=make_blobs(n_samples=50, centers=2, random_state=0, cluster_std=0.60)
plt.scatter(X[:, 0],X[:, 1],c=y,s=50,cmap='summer')

# %% [markdown]
# Decision Boundries

# %%
xfit=np.linspace(-1,3.5)
plt.scatter(X[:, 0],X[:, 1],c=y,s=50,cmap='summer')
plt.plot([0.6],[2.1],'x',color='green',markeredgewidth=2,markersize=10)

#Taking some samples values of slope(m) and intercept(b) for boundries
for m,b in[(1,0.65),(0.5,1.6),(-0.2,2.9)]:
  plt.plot(xfit,m*xfit+b, '-k')

plt.xlim(-1,3.5)
# Out:
# (-1.0, 3.5)

# %% [markdown]
# Using MARGIN for finding the better Decision Boundies out of all

# %% [markdown]
# Pltting the margins

# %%
xfit=np.linspace(-1,3.5)
plt.scatter(X[:, 0],X[:, 1],c=y,s=50,cmap='summer')

#d is for weight of margin
for m, b, d in [(1,0.65,0.33),(0.5,1.6,0.55),(-0.2,2.9,0.2)]:
  yfit=m*xfit+b
  plt.plot(xfit,yfit, '-k')
  plt.fill_between(xfit,yfit -d,yfit +d,edgecolor='none',color='#AAAAAA',alpha=0.4)

plt.xlim(-1,3.5)
# Out:
# (-1.0, 3.5)

# %% [markdown]
# *Now SVM takes the best decision boundries from these for classification*
